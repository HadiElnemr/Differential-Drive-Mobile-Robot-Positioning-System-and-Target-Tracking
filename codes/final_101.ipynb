# %% [markdown]
# # Imports

# %%
import cv2
import math
import numpy as np
import socket
import matplotlib.pyplot as plt
from cv2 import aruco
from scipy.interpolate import interp1d
mapper=interp1d([0,90],[155,255])
mapperd=interp1d([0,2000],[155,255])

# %% [markdown]
# # Aruco Markers Initialization

# %%
# Aruco Parameters
num_mark = 20 #Number of markers
size_mark = 500 #Size of markers


### Create Aruco markers 
dict_aruco = aruco.Dictionary_get(aruco.DICT_4X4_50)

front_marker_idx = 1
front_marker = aruco.drawMarker(dict_aruco, front_marker_idx, size_mark)
# cv2.imshow("fd ",front_marker)
# cv2.waitKey(0)
# cv2.destroyAllWindows()
rear_marker_idx = 2
rear_marker = aruco.drawMarker(dict_aruco, rear_marker_idx, size_mark)
target1_marker_idx = 3
target2_marker_idx = 4
target3_marker_idx = 5
target1_marker = aruco.drawMarker(dict_aruco, target1_marker_idx, size_mark) 
target2_marker = aruco.drawMarker(dict_aruco, target2_marker_idx, size_mark)
target3_marker = aruco.drawMarker(dict_aruco, target3_marker_idx, size_mark)
# cv2.imshow("fjd ",target_1_marker)
# cv2.waitKey(0)
# cv2.destroyAllWindows()
target_markers = [target1_marker, target2_marker, target3_marker]
target_marker_ids = [target1_marker_idx, target2_marker_idx, target3_marker_idx]

parameters = aruco.DetectorParameters_create()

# %% [markdown]
# # Helper Functions

# %%
def preprocess_corners(corners, ids):  
    ids = ids.tolist()
    if front_marker_idx in ids:
        front_corner_idx = ids.index(front_marker_idx)
        front_marker_centre = get_marker_centre(corners[front_corner_idx])
    else:
        front_marker_centre = None
                 
    if rear_marker_idx in ids:
        rear_corner_idx = ids.index(rear_marker_idx)
        rear_marker_centre = get_marker_centre(corners[rear_corner_idx])
    else:
        rear_marker_centre = None 
        
    if target1_marker_idx in ids:
        target1_corner_idx = ids.index(target1_marker_idx)
        target1_marker_centre = get_marker_centre(corners[target1_corner_idx])
    else:
        target1_marker_centre = None
  
        
    if target2_marker_idx in ids:
        target2_corner_idx = ids.index(target2_marker_idx)
        target2_marker_centre = get_marker_centre(corners[target2_corner_idx])
    else:
        target2_marker_centre = None
        
    if target3_marker_idx in ids:
        target3_corner_idx = ids.index(target3_marker_idx)
        target3_marker_centre = get_marker_centre(corners[target3_corner_idx])
    else:
        target3_marker_centre = None
        

    return [front_marker_centre, rear_marker_centre, target1_marker_centre, target2_marker_centre, target3_marker_centre]
            
def get_robot_centre(front_marker_centre, rear_marker_centre):
    return np.array([(front_marker_centre[0]+rear_marker_centre[0])/2 , (front_marker_centre[1]+rear_marker_centre[1])/2])


def get_marker_centre(corner):
    cornerUL = corner[0][0]
    cornerUR = corner[0][1]
    cornerBR = corner[0][2]
    cornerBL = corner[0][3]
    return np.array([ (cornerUL[0]+cornerBR[0])/2 , (cornerUL[1]+cornerBR[1])/2 ])

# def get_vehicle_horizontal_orientation(left_wheel_pos, right_wheel_pos):


# def get_robot_heading(front_centre, rear_centre):
#     return front_centre - rear_centre # as np array

### Corrected: robot heading is the direction or angle
def get_robot_heading(front_centre, rear_centre):
    return get_vector_angle(front_centre - rear_centre) # as np array

def get_target_vector(robot_centre, target_centre):
    return target_centre - robot_centre # as np array

def get_vector_angle(vector):
    return math.atan2(vector[0],vector[1])*(180/math.pi)

def get_heading_error(robot_heading, target_angle):
    return (target_angle - robot_heading + 180) % 360 - 180

def get_rotation_direction(heading_error):
    #mode 1 rotates counter clockwise
    #mode -1 rotates clockwise
    if abs(heading_error) <= 90:
        return int(np.sign(heading_error) )
    return - int(np.sign(heading_error))

def get_abs_heading_error(heading_error):
    if abs(heading_error) <= 90:
        return abs(heading_error)
    return abs(180-abs(heading_error)) 

def get_distance_to_target(robot_centre, target_centre):
    return np.linalg.norm(get_target_vector(robot_centre, target_centre))

def get_longitudinal_direction(heading_error):
    if abs(heading_error) <= 90:
        return 0 #mode 0 moves forward
    return 2 #mode 2 moves backwards

# %% [markdown]
# # Communication initialization

# %%
# Replace with the IP address of the ESP32
UDP_IP = "192.168.43.57"
# UDP_IP = "192.168.164.112"
UDP_PORT = 8080
# Create a UDP socket
sock = socket.socket(socket.AF_INET, socket.SOCK_DGRAM)

font                   = cv2.FONT_HERSHEY_SIMPLEX
fontScale              = 1
fontColor              = (0,0,255)
thickness              = 2
lineType               = 2
camera_on = True
if camera_on:
    cap = cv2.VideoCapture(0)

# %% [markdown]
# # Main()

# %%
### Load the video
PWM1=0
PWM2=0
mode=0
#to be tuned
kpr=0.05
kpd=3
# if not camera_on:
#     kpd=3.3
# else:
#     kpd=5
kpoff=0.2
while True:
    # Capture a frame
    if camera_on:
        ret, frame = cap.read()
    files = ['testBack.png', 'testClock.png', 'testFor2.png', 'testBack2.png', 'testCounter2.png',
             'testFor3.png', 'testBack.png', 'testCounter.png', 'testFor.png']
    if not camera_on:
        frame = cv2.imread(files[-1])
    
    
    # Convert the frame to grayscale
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    cv2.imshow('Original Image', gray)
    cv2.waitKey(1)
    corners, ids, rejectedImgPoints = aruco.detectMarkers(gray, dict_aruco, parameters=parameters)
    list_ids = np.ravel(ids)
    
    front_marker_centre, rear_marker_centre, target1_marker_centre, \
     target2_marker_centre, target3_marker_centre = preprocess_corners(corners, list_ids)
    #TODO user input
    if  front_marker_centre is None or  rear_marker_centre is None or target1_marker_centre is None:
        message = str(0) + ',' + str(0) + ',' + str(0)
        data = message.encode()
        sock.sendto(data, (UDP_IP, UDP_PORT))
        continue
    target_centre = target1_marker_centre
    robot_centre= get_robot_centre(front_marker_centre, rear_marker_centre)
    robot_heading= get_robot_heading(front_marker_centre, rear_marker_centre)
    target_vector=get_target_vector(robot_centre, target_centre)
    target_angle=get_vector_angle(target_vector)
    heading_error=get_heading_error(robot_heading, target_angle)
    absHeadingError=get_abs_heading_error(heading_error)
    
    # Drawing on frame
    bottomLeftCornerOfText = tuple(robot_centre.astype(int))
    cv2.arrowedLine(frame, tuple(robot_centre.astype(int)), tuple(target_centre.astype(int)), (255,0,0), thickness=3) 
    cv2.arrowedLine(frame, tuple(robot_centre.astype(int)), tuple(front_marker_centre.astype(int)), (255,0,0), thickness=3) 
    cv2.putText(frame,str(round(heading_error))+" + mode: "+str(get_longitudinal_direction(heading_error)),
    bottomLeftCornerOfText,
    font,      
    fontScale, 
    fontColor, 
    thickness, 
    lineType)
    
    cv2.imshow('Original Image', frame)
    cv2.waitKey(1)
    
    
    if (absHeadingError>5):
        #rotate around itslef
        controledAngleError = kpr * absHeadingError
        PWM1 = mapper(controledAngleError)
        PWM2 = PWM1
        mode = get_rotation_direction(heading_error)
        
    else:
        #Move to target
        errord = get_distance_to_target(robot_centre, target_centre)
        if(errord<20):
            avgSpeed = 0
        else:
            print(kpd*errord)
            avgSpeed = mapperd(min(kpd*errord, 2000))
        if(absHeadingError < 2):
            offset = 0
        else:
            offset = kpoff * absHeadingError
        mode = get_longitudinal_direction(heading_error)
        rotationDirection = get_rotation_direction(heading_error)
        print("rotationDirection ",rotationDirection)
        # at mode zero(Forwards) PWM1 Left------PWM2 Right
        #at mode 2 (Backwards) PWM1 Right --------- PWM2 Left
        if mode==0:
            if(rotationDirection == 1):
                PWM2 = avgSpeed + offset
                PWM1 = avgSpeed - offset  
            else:
                PWM2 = avgSpeed - offset
                PWM1 = avgSpeed + offset
        else:
            if(rotationDirection == -1):
                PWM2 = avgSpeed + offset
                PWM1 = avgSpeed - offset
            else:
                PWM2 = avgSpeed - offset
                PWM1 = avgSpeed + offset
    print("target_centre ",target_centre)
    print("robot_centre ",robot_centre)
    print("robot_heading ",robot_heading)
    print("target_vector ",target_vector)
    print("target_angle ",target_angle)
    print("heading_error ",heading_error)
    print("absHeadingError ",absHeadingError)
    print("PWM1 ",PWM1,"PWM2 ",PWM2,"mode ",mode)
    message = str(PWM1) + ',' + str(PWM2) + ',' + str(mode)
    ###
    data = message.encode()
    sock.sendto(data, (UDP_IP, UDP_PORT))
#     bytesAddressPair = sock.recvfrom(1024)
#     message = bytesAddressPair[0].decode()
#     address = bytesAddressPair[1]
    print(message)
    ###
    
    if cv2.waitKey(1) == 13: #13 Enter Key
        break
    #send signal to arduino
#      if list_ids[0] == 5:
#         data = str(0).encode()
#     elif avg_intensity > 80:
#         data = str(1).encode()
#     else:
#         data = str(-1).encode()
    
#     sock.sendto(data, (UDP_IP, UDP_PORT))
    
#     bytesAddressPair = sock.recvfrom(1024)

#     message = bytesAddressPair[0].decode()
#     address = bytesAddressPair[1]
#     print(message)
     #,end="\r"


cap.release()                                             # For releasing cap and out. 
cv2.destroyAllWindows()
# Out:
# on
# target_centre  [580.5 277. ]
# robot_centre  [435.5 362.5]
# robot_heading  -45.0
# target_vector  [145.  -85.5]
# target_angle  120.52594707428098
# heading_error  165.52594707428096
# absHeadingError  14.474052925719036
# PWM1  155.80411405142883 PWM2  155.80411405142883 mode  -1
# 155.80411405142883,155.80411405142883,-1
# target_centre  [580.5 277. ]
# robot_centre  [435.25 362.25]
# robot_heading  -43.49256424122503
# target_vector  [145.25 -85.25]
# target_angle  120.40948675012154
# heading_error  163.90205099134658
# absHeadingError  16.097949008653416
# PWM1  155.89433050048075 PWM2  155.89433050048075 mode  -1
# 155.89433050048075,155.89433050048075,-1
# target_centre  [580.5 277. ]
# robot_centre  [435.75 362.75]
# robot_heading  -43.49256424122503
# target_vector  [144.75 -85.75]
# target_angle  120.64252973739549
# heading_error  164.1350939786205
# absHeadingError  15.864906021379511
# PWM1  155.8813836678544 PWM2  155.8813836678544 mode  -1
# 155.8813836678544,155.8813836678544,-1
# target_centre  [580.5 277. ]
# robot_centre  [435.75 362.75]
# robot_heading  -43.49256424122503
# target_vector  [144.75 -85.75]
# target_angle  120.64252973739549
# heading_error  164.1350939786205
# absHeadingError  15.864906021379511
# PWM1  155.8813836678544 PWM2  155.8813836678544 mode  -1
# 155.8813836678544,155.8813836678544,-1
# target_centre  [580.5 277. ]
# robot_centre  [435.5 362.5]
# robot_heading  -45.0
# target_vector  [145.  -85.5]
# target_angle  120.52594707428098
# heading_error  165.52594707428096
# absHeadingError  14.474052925719036
# PWM1  155.80411405142883 PWM2  155.80411405142883 mode  -1
# 155.80411405142883,155.80411405142883,-1
# target_centre  [581.  276.5]
# robot_centre  [435.75 362.75]
# robot_heading  -43.49256424122503
# target_vector  [145.25 -86.25]
# target_angle  120.70200098480188
# heading_error  164.19456522602695
# absHeadingError  15.805434773973047
# PWM1  155.87807970966517 PWM2  155.87807970966517 mode  -1
# 155.87807970966517,155.87807970966517,-1
# target_centre  [580.5 277. ]
# robot_centre  [435.5 362.5]
# robot_heading  -45.0
# target_vector  [145.  -85.5]
# target_angle  120.52594707428098
# heading_error  165.52594707428096
# absHeadingError  14.474052925719036
# PWM1  155.80411405142883 PWM2  155.80411405142883 mode  -1
# 155.80411405142883,155.80411405142883,-1
# target_centre  [581.  276.5]
# robot_centre  [435.25 362.25]
# robot_heading  -43.49256424122503
# target_vector  [145.75 -85.75]
# target_angle  120.46983963345478
# heading_error  163.9624038746798
# absHeadingError  16.037596125320192
# PWM1  155.89097756251778 PWM2  155.89097756251778 mode  -1
# 155.89097756251778,155.89097756251778,-1
# target_centre  [580.5 277. ]
# robot_centre  [435.5 362.5]
# robot_heading  -45.0
# target_vector  [145.  -85.5]
# target_angle  120.52594707428098
# heading_error  165.52594707428096
# absHeadingError  14.474052925719036
# PWM1  155.80411405142883 PWM2  155.80411405142883 mode  -1
# 155.80411405142883,155.80411405142883,-1
# target_centre  [580.5 277. ]
# robot_centre  [435.25 362.25]
# robot_heading  -45.0
# target_vector  [145.25 -85.25]
# target_angle  120.40948675012154
# heading_error  165.40948675012157
# absHeadingError  14.590513249878427
# PWM1  155.81058406943768 PWM2  155.81058406943768 mode  -1
# 155.81058406943768,155.81058406943768,-1
# target_centre  [580.5 277. ]
# robot_centre  [435.5 362. ]
# robot_heading  -45.0
# target_vector  [145. -85.]
# target_angle  120.37912601136834
# heading_error  165.37912601136833
# absHeadingError  14.620873988631672
# PWM1  155.8122707771462 PWM2  155.8122707771462 mode  -1
# 155.8122707771462,155.8122707771462,-1
# target_centre  [580.5 277. ]
# robot_centre  [435.5 362. ]
# robot_heading  -45.0
# target_vector  [145. -85.]
# target_angle  120.37912601136834
# heading_error  165.37912601136833
# absHeadingError  14.620873988631672
# PWM1  155.8122707771462 PWM2  155.8122707771462 mode  -1
# 155.8122707771462,155.8122707771462,-1
# target_centre  [580.5 277. ]
# robot_centre  [435.5 362. ]
# robot_heading  -45.0
# target_vector  [145. -85.]
# target_angle  120.37912601136834
# heading_error  165.37912601136833
# absHeadingError  14.620873988631672
# PWM1  155.8122707771462 PWM2  155.8122707771462 mode  -1
# 155.8122707771462,155.8122707771462,-1
# target_centre  [581.  276.5]
# robot_centre  [435.25 361.75]
# robot_heading  -46.50743575877497
# target_vector  [145.75 -85.25]
# target_angle  120.32360686255
# heading_error  166.83104262132497
# absHeadingError  13.168957378675032
# PWM1  155.73160874325973 PWM2  155.73160874325973 mode  -1
# 155.73160874325973,155.73160874325973,-1
# target_centre  [581.  276.5]
# robot_centre  [435.25 361.25]
# robot_heading  -45.0
# target_vector  [145.75 -84.75]
# target_angle  120.17693618630096
# heading_error  165.17693618630096
# absHeadingError  14.823063813699036
# PWM1  155.8235035452055 PWM2  155.8235035452055 mode  -1
# 155.8235035452055,155.8235035452055,-1
# target_centre  [580.5 277. ]
# robot_centre  [435.25 361.25]
# robot_heading  -45.0
# target_vector  [145.25 -84.25]
# target_angle  120.11520897148833
# heading_error  165.1152089714883
# absHeadingError  14.8847910285117
# PWM1  155.82693283491733 PWM2  155.82693283491733 mode  -1
# 155.82693283491733,155.82693283491733,-1
# target_centre  [580.5 277. ]
# robot_centre  [435.25 361.25]
# robot_heading  -45.0
# target_vector  [145.25 -84.25]
# target_angle  120.11520897148833
# heading_error  165.1152089714883
# absHeadingError  14.8847910285117
# PWM1  155.82693283491733 PWM2  155.82693283491733 mode  -1
# 155.82693283491733,155.82693283491733,-1
# target_centre  [580.5 277. ]
# robot_centre  [435.25 361.  ]
# robot_heading  -44.27477570094075
# target_vector  [145.25 -84.  ]
# target_angle  120.04136392627913
# heading_error  164.31613962721985
# absHeadingError  15.683860372780146
# PWM1  155.87132557626558 PWM2  155.87132557626558 mode  -1
# 155.87132557626558,155.87132557626558,-1
# target_centre  [580.5 277. ]
# robot_centre  [435.25 361.25]
# robot_heading  -45.0
# target_vector  [145.25 -84.25]
# target_angle  120.11520897148833
# heading_error  165.1152089714883
# absHeadingError  14.8847910285117
# PWM1  155.82693283491733 PWM2  155.82693283491733 mode  -1
# 155.82693283491733,155.82693283491733,-1
# target_centre  [580.5 277. ]
# robot_centre  [435.5 361. ]
# robot_heading  -45.0
# target_vector  [145. -84.]
# target_angle  120.08415655877519
# heading_error  165.0841565587752
# absHeadingError  14.915843441224808
# PWM1  155.82865796895695 PWM2  155.82865796895695 mode  -1
# 155.82865796895695,155.82865796895695,-1
# target_centre  [580.5 277. ]
# robot_centre  [435.25 361.  ]
# robot_heading  -45.744059202888714
# target_vector  [145.25 -84.  ]
# target_angle  120.04136392627913
# heading_error  165.78542312916784
# absHeadingError  14.214576870832161
# PWM1  155.78969871504623 PWM2  155.78969871504623 mode  -1
# 155.78969871504623,155.78969871504623,-1
# target_centre  [580.5 277. ]
# robot_centre  [435.25 359.5 ]
# robot_heading  -47.290610042638534
# target_vector  [145.25 -82.5 ]
# target_angle  119.59597854823248
# heading_error  166.88658859087104
# absHeadingError  13.113411409128958
# PWM1  155.7285228560627 PWM2  155.7285228560627 mode  -1
# 155.7285228560627,155.7285228560627,-1
# target_centre  [580.5 277. ]
# robot_centre  [435.25 358.75]
# robot_heading  -46.43209618416465
# target_vector  [145.25 -81.75]
# target_angle  119.37179777312845
# heading_error  165.8038939572931
# absHeadingError  14.196106042706901
# PWM1  155.78867255792815 PWM2  155.78867255792815 mode  -1
# 155.78867255792815,155.78867255792815,-1
# target_centre  [580.5 277. ]
# robot_centre  [435.25 358.25]
# robot_heading  -47.93567344642118
# target_vector  [145.25 -81.25]
# target_angle  119.22179294323884
# heading_error  167.15746638966004
# absHeadingError  12.842533610339956
# PWM1  155.71347408946332 PWM2  155.71347408946332 mode  -1
# 155.71347408946332,155.71347408946332,-1
# target_centre  [580.5 277. ]
# robot_centre  [435.25 358.25]
# robot_heading  -47.93567344642118
# target_vector  [145.25 -81.25]
# target_angle  119.22179294323884
# heading_error  167.15746638966004
# absHeadingError  12.842533610339956
# PWM1  155.71347408946332 PWM2  155.71347408946332 mode  -1
# 155.71347408946332,155.71347408946332,-1
# target_centre  [580.5 277. ]
# robot_centre  [435.25 357.25]
# robot_heading  -49.513988458001265
# target_vector  [145.25 -80.25]
# target_angle  118.9204614597403
# heading_error  168.43444991774157
# absHeadingError  11.565550082258426
# PWM1  155.64253056012546 PWM2  155.64253056012546 mode  -1
# 155.64253056012546,155.64253056012546,-1
# target_centre  [580.5 277. ]
# robot_centre  [435.5 357. ]
# robot_heading  -49.398705354995535
# target_vector  [145. -80.]
# target_angle  118.88658176691071
# heading_error  168.2852871219062
# absHeadingError  11.714712878093792
# PWM1  155.65081738211632 PWM2  155.65081738211632 mode  -1
# 155.65081738211632,155.65081738211632,-1
# target_centre  [580.5 277. ]
# robot_centre  [435.5 357. ]
# robot_heading  -49.398705354995535
# target_vector  [145. -80.]
# target_angle  118.88658176691071
# heading_error  168.2852871219062
# absHeadingError  11.714712878093792
# PWM1  155.65081738211632 PWM2  155.65081738211632 mode  -1
# 155.65081738211632,155.65081738211632,-1
# target_centre  [580.5 277. ]
# robot_centre  [435.5  356.25]
# robot_heading  -50.19442890773481
# target_vector  [145.   -79.25]
# target_angle  118.65888641808871
# heading_error  168.85331532582353
# absHeadingError  11.14668467417647
# PWM1  155.61926025967648 PWM2  155.61926025967648 mode  -1
# 155.61926025967648,155.61926025967648,-1
# target_centre  [580.5 277. ]
# robot_centre  [435.5  356.25]
# robot_heading  -50.19442890773481
# target_vector  [145.   -79.25]
# target_angle  118.65888641808871
# heading_error  168.85331532582353
# absHeadingError  11.14668467417647
# PWM1  155.61926025967648 PWM2  155.61926025967648 mode  -1
# 155.61926025967648,155.61926025967648,-1
# target_centre  [580.5 277. ]
# robot_centre  [435.5 355.5]
# robot_heading  -52.69605172201657
# target_vector  [145.  -78.5]
# target_angle  118.43019764367895
# heading_error  171.12624936569551
# absHeadingError  8.873750634304486
# PWM1  155.49298614635026 PWM2  155.49298614635026 mode  -1
# 155.49298614635026,155.49298614635026,-1
# target_centre  [580.5 277. ]
# robot_centre  [435.5  355.25]
# robot_heading  -51.84277341263094
# target_vector  [145.   -78.25]
# target_angle  118.35374742858835
# heading_error  170.1965208412193
# absHeadingError  9.803479158780704
# PWM1  155.54463773104337 PWM2  155.54463773104337 mode  -1
# 155.54463773104337,155.54463773104337,-1
# target_centre  [580.5 277. ]
# robot_centre  [435.75 354.25]
# robot_heading  -52.49585763972986
# target_vector  [144.75 -77.25]
# target_angle  118.08789316820902
# heading_error  170.58375080793888
# absHeadingError  9.416249192061116
# PWM1  155.5231249551145 PWM2  155.5231249551145 mode  -1
# 155.5231249551145,155.5231249551145,-1
# target_centre  [580.5 277. ]
# robot_centre  [435.75 353.75]
# robot_heading  -52.49585763972986
# target_vector  [144.75 -76.75]
# target_angle  117.93363198403112
# heading_error  170.42948962376101
# absHeadingError  9.570510376238985
# PWM1  155.53169502090216 PWM2  155.53169502090216 mode  -1
# 155.53169502090216,155.53169502090216,-1
# target_centre  [580.5 277. ]
# robot_centre  [436.   353.25]
# robot_heading  -54.833563964207116
# target_vector  [144.5  -76.25]
# target_angle  117.81978891671913
# heading_error  172.65335288092626
# absHeadingError  7.346647119073737
# PWM1  155.40814706217077 PWM2  155.40814706217077 mode  -1
# 155.40814706217077,155.40814706217077,-1
# target_centre  [580.5 277. ]
# robot_centre  [436.   352.75]
# robot_heading  -54.833563964207116
# target_vector  [144.5  -75.75]
# target_angle  117.66449251761313
# heading_error  172.49805648182024
# absHeadingError  7.501943518179758
# PWM1  155.41677463989888 PWM2  155.41677463989888 mode  -1
# 155.41677463989888,155.41677463989888,-1
# target_centre  [580.5 277. ]
# robot_centre  [436.5  351.75]
# robot_heading  -56.02345596374314
# target_vector  [144.   -74.75]
# target_angle  117.43370077877901
# heading_error  173.45715674252216
# absHeadingError  6.542843257477841
# PWM1  155.3634912920821 PWM2  155.3634912920821 mode  -1
# 155.3634912920821,155.3634912920821,-1
# target_centre  [580.5 277. ]
# robot_centre  [436.5 351.5]
# robot_heading  -55.175510843043206
# target_vector  [144.  -74.5]
# target_angle  117.35528767950719
# heading_error  172.5307985225504
# absHeadingError  7.469201477449587
# PWM1  155.4149556376361 PWM2  155.4149556376361 mode  -1
# 155.4149556376361,155.4149556376361,-1
# target_centre  [580.5 277. ]
# robot_centre  [436.5 351. ]
# robot_heading  -56.88865803962798
# target_vector  [144. -74.]
# target_angle  117.19812794850912
# heading_error  174.08678598813708
# absHeadingError  5.9132140118629195
# PWM1  155.32851188954794 PWM2  155.32851188954794 mode  -1
# 155.32851188954794,155.32851188954794,-1
# target_centre  [580.5 277. ]
# robot_centre  [436.75 350.25]
# robot_heading  -57.20046872738079
# target_vector  [143.75 -73.25]
# target_angle  117.00180888117104
# heading_error  174.20227760855187
# absHeadingError  5.797722391448133
# PWM1  155.32209568841378 PWM2  155.32209568841378 mode  -1
# 155.32209568841378,155.32209568841378,-1
# 484.3397567823645
# rotationDirection  -1
# target_centre  [580.5 277. ]
# robot_centre  [436.5 350. ]
# robot_heading  -58.67130713219584
# target_vector  [144. -73.]
# target_angle  116.88247607083046
# heading_error  175.55378320302634
# absHeadingError  4.446216796973658
# PWM1  178.3277444797235 PWM2  180.10623119851294 mode  2
# 178.3277444797235,180.10623119851294,2
# 481.64950949834883
# rotationDirection  -1
# target_centre  [580.5 277. ]
# robot_centre  [437. 349.]
# robot_heading  -58.67130713219584
# target_vector  [143.5 -72. ]
# target_angle  116.6448502612927
# heading_error  175.31615739348854
# absHeadingError  4.683842606511462
# PWM1  178.14570695361513 PWM2  180.01924399621973 mode  2
# 178.14570695361513,180.01924399621973,2
# 480.9786897566253
# rotationDirection  -1
# target_centre  [580.5 277. ]
# robot_centre  [437.  348.5]
# robot_heading  -58.67130713219584
# target_vector  [143.5 -71.5]
# target_angle  116.48514079721362
# heading_error  175.15644792940947
# absHeadingError  4.843552070590533
# PWM1  178.08022407371317 PWM2  180.01764490194938 mode  2
# 178.08022407371317,180.01764490194938,2
# 479.63951307205707
# rotationDirection  -1
# target_centre  [580.5 277. ]
# robot_centre  [437.25 348.  ]
# robot_heading  -59.215853473673555
# target_vector  [143.25 -71.  ]
# target_angle  116.36471710007017
# heading_error  175.58057057374373
# absHeadingError  4.419429426256272
# PWM1  178.0980897683516 PWM2  179.86586153885412 mode  2
# 178.0980897683516,179.86586153885412,2
# 478.6345813875132
# rotationDirection  -1
# target_centre  [580.5 277. ]
# robot_centre  [437.5  347.75]
# robot_heading  -61.476881393687975
# target_vector  [143.   -70.75]
# target_angle  116.32414532476514
# heading_error  177.8010267184531
# absHeadingError  2.1989732815468983
# PWM1  178.49193441306628 PWM2  179.37152372568502 mode  2
# 178.49193441306628,179.37152372568502,2
# target_centre  [580.5 277. ]
# robot_centre  [438.75 346.75]
# robot_heading  -58.32453126189079
# target_vector  [141.75 -69.75]
# target_angle  116.20011484134734
# heading_error  174.52464610323813
# absHeadingError  5.475353896761874
# PWM1  155.30418632759788 PWM2  155.30418632759788 mode  -1
# 155.30418632759788,155.30418632759788,-1
# 467.5791376868733
# rotationDirection  -1
# target_centre  [580.5 277. ]
# robot_centre  [440.5 345.5]
# robot_heading  -59.743562836470744
# target_vector  [140.  -68.5]
# target_angle  116.07184287599453
# heading_error  175.8154057124653
# absHeadingError  4.184594287534708
# PWM1  177.54203802683674 PWM2  179.2158757418506 mode  2
# 177.54203802683674,179.2158757418506,2
# 460.8711859077328
# rotationDirection  -1
# target_centre  [580.5 277. ]
# robot_centre  [442.5 344.5]
# robot_heading  -60.52411099675425
# target_vector  [138.  -67.5]
# target_angle  116.06466407828577
# heading_error  176.58877507504002
# absHeadingError  3.4112249249599813
# PWM1  177.36131431039465 PWM2  178.72580428037864 mode  2
# 177.36131431039465,178.72580428037864,2
# target_centre  [580.5 277. ]
# robot_centre  [445.5 343. ]
# robot_heading  -58.67130713219584
# target_vector  [135. -66.]
# target_angle  116.05349531049094
# heading_error  174.72480244268678
# absHeadingError  5.27519755731322
# PWM1  155.29306653096185 PWM2  155.29306653096185 mode  -1
# 155.29306653096185,155.29306653096185,-1
# 443.7579576751273
# rotationDirection  -1
# target_centre  [580.5 277. ]
# robot_centre  [447.75 342.25]
# robot_heading  -60.124007308310574
# target_vector  [132.75 -65.25]
# target_angle  116.17528998175993
# heading_error  176.2992972900705
# absHeadingError  3.7007027099294874
# PWM1  176.44775734177045 PWM2  177.92803842574227 mode  2
# 176.44775734177045,177.92803842574227,2
# 437.7392203127337
# rotationDirection  -1
# target_centre  [580.5 277. ]
# robot_centre  [449.25 340.75]
# robot_heading  -61.99082329198616
# target_vector  [131.25 -63.75]
# target_angle  115.90650799951439
# heading_error  177.89733129150056
# absHeadingError  2.1026687084994364
# PWM1  176.4664272739368 PWM2  177.3074947573366 mode  2
# 176.4664272739368,177.3074947573366,2
# 435.40907489394385
# rotationDirection  -1
# target_centre  [581.  276.5]
# robot_centre  [450.25 339.5 ]
# robot_heading  -62.94940299291389
# target_vector  [130.75 -63.  ]
# target_angle  115.72642092397832
# heading_error  178.67582391689223
# absHeadingError  1.3241760831077727
# PWM1  176.7704537446972 PWM2  176.7704537446972 mode  2
# 176.7704537446972,176.7704537446972,2
# 426.05347375652275
# rotationDirection  -1
# target_centre  [580.5 277. ]
# robot_centre  [452.25 338.  ]
# robot_heading  -63.90457584261166
# target_vector  [128.25 -61.  ]
# target_angle  115.4373271512193
# heading_error  179.34190299383096
# absHeadingError  0.6580970061690437
# PWM1  176.30267368782614 PWM2  176.30267368782614 mode  2
# 176.30267368782614,176.30267368782614,2
# 421.7388113512912
# rotationDirection  1
# target_centre  [580.5 277. ]
# robot_centre  [453.25 336.75]
# robot_heading  -64.85521436932105
# target_vector  [127.25 -59.75]
# target_angle  115.1523151371095
# heading_error  -179.99247049356944
# absHeadingError  0.007529506430557831
# PWM1  176.08694056756457 PWM2  176.08694056756457 mode  2
# 176.08694056756457,176.08694056756457,2
# 417.07081233287
# rotationDirection  1
# target_centre  [581.  276.5]
# robot_centre  [455.   335.25]
# robot_heading  -66.37062226934319
# target_vector  [126.   -58.75]
# target_angle  114.9982202209079
# heading_error  -178.6311575097489
# absHeadingError  1.3688424902510974
# PWM1  175.8535406166435 PWM2  175.8535406166435 mode  2
# 175.8535406166435,175.8535406166435,2
# 409.3687976629387
# rotationDirection  1
# target_centre  [581.  276.5]
# robot_centre  [457.25 334.  ]
# robot_heading  -65.82089285331082
# target_vector  [123.75 -57.5 ]
# target_angle  114.9217705225852
# heading_error  -179.25733662410397
# absHeadingError  0.7426633758960293
# PWM1  175.46843988314694 PWM2  175.46843988314694 mode  2
# 175.46843988314694,175.46843988314694,2
# 396.69328517130214
# rotationDirection  1
# target_centre  [580.5 277. ]
# robot_centre  [460.25 332.  ]
# robot_heading  -65.82089285331082
# target_vector  [120.25 -55.  ]
# target_angle  114.57843062372596
# heading_error  -179.60067652296323
# absHeadingError  0.3993234770367735
# PWM1  174.8346642585651 PWM2  174.8346642585651 mode  2
# 174.8346642585651,174.8346642585651,2
# 385.9549844217587
# rotationDirection  -1
# target_centre  [580.5 277. ]
# robot_centre  [463.5 330.5]
# robot_heading  -64.35899417569472
# target_vector  [117.  -53.5]
# target_angle  114.57295760411155
# heading_error  178.93195177980624
# absHeadingError  1.0680482201937593
# PWM1  174.29774922108794 PWM2  174.29774922108794 mode  2
# 174.29774922108794,174.29774922108794,2
# 376.52390362366106
# rotationDirection  -1
# target_centre  [580.5 277. ]
# robot_centre  [466.5 329.5]
# robot_heading  -64.35899417569472
# target_vector  [114.  -52.5]
# target_angle  114.72731438669014
# heading_error  179.08630856238483
# absHeadingError  0.9136914376151708
# PWM1  173.82619518118304 PWM2  173.82619518118304 mode  2
# 173.82619518118304,173.82619518118304,2
# 366.46691528704196
# rotationDirection  -1
# target_centre  [580.5 277. ]
# robot_centre  [469.5 328. ]
# robot_heading  -64.35899417569472
# target_vector  [111. -51.]
# target_angle  114.67686317033706
# heading_error  179.03585734603178
# absHeadingError  0.9641426539682243
# PWM1  173.3233457643521 PWM2  173.3233457643521 mode  2
# 173.3233457643521,173.3233457643521,2
# 354.7341434088351
# rotationDirection  -1
# target_centre  [580.5 277. ]
# robot_centre  [473.   326.25]
# robot_heading  -64.39781244855823
# target_vector  [107.5  -49.25]
# target_angle  114.61438791757658
# heading_error  179.01220036613483
# absHeadingError  0.9877996338651656
# PWM1  172.73670717044175 PWM2  172.73670717044175 mode  2
# 172.73670717044175,172.73670717044175,2
# 343.99582119554884
# rotationDirection  -1
# target_centre  [580.5 277. ]
# robot_centre  [476.25 324.75]
# robot_heading  -64.85521436932105
# target_vector  [104.25 -47.75]
# target_angle  114.60936977955512
# heading_error  179.46458414887616
# absHeadingError  0.5354158511238438
# PWM1  172.19979105977745 PWM2  172.19979105977745 mode  2
# 172.19979105977745,172.19979105977745,2
# 331.581437960571
# rotationDirection  -1
# target_centre  [580.5 277. ]
# robot_centre  [480. 323.]
# robot_heading  -65.37643521383639
# target_vector  [100.5 -46. ]
# target_angle  114.5941118520651
# heading_error  179.97054706590148
# absHeadingError  0.029452934098515016
# PWM1  171.57907189802856 PWM2  171.57907189802856 mode  2
# 171.57907189802856,171.57907189802856,2
# 310.417561519963
# rotationDirection  -1
# target_centre  [580.5 277. ]
# robot_centre  [486.5  320.25]
# robot_heading  -64.39781244855823
# target_vector  [ 94.   -43.25]
# target_angle  114.70746080675774
# heading_error  179.10527325531598
# absHeadingError  0.8947267446840215
# PWM1  170.52087807599816 PWM2  170.52087807599816 mode  2
# 170.52087807599816,170.52087807599816,2
# 299.3665186690055
# rotationDirection  -1
# target_centre  [580.5 277. ]
# robot_centre  [489.75 318.5 ]
# robot_heading  -64.91640599380908
# target_vector  [ 90.75 -41.5 ]
# target_angle  114.57463122284587
# heading_error  179.49103721665495
# absHeadingError  0.508962783345055
# PWM1  169.96832593345027 PWM2  169.96832593345027 mode  2
# 169.96832593345027,169.96832593345027,2
# 291.9273240037664
# rotationDirection  -1
# target_centre  [581.  276.5]
# robot_centre  [492.75 317.5 ]
# robot_heading  -64.91640599380908
# target_vector  [ 88.25 -41.  ]
# target_angle  114.91907367951396
# heading_error  179.83547967332305
# absHeadingError  0.16452032667694994
# PWM1  169.59636620018833 PWM2  169.59636620018833 mode  2
# 169.59636620018833,169.59636620018833,2
# 288.6282210734079
# rotationDirection  -1
# target_centre  [583.5 275.5]
# robot_centre  [496.  315.5]
# robot_heading  -63.43494882292201
# target_vector  [ 87.5 -40. ]
# target_angle  114.56717132060132
# heading_error  178.0021201435233
# absHeadingError  1.9978798564766862
# PWM1  169.4314110536704 PWM2  169.4314110536704 mode  2
# 169.4314110536704,169.4314110536704,2
# 295.70361005574483
# rotationDirection  -1
# target_centre  [589.  273.5]
# robot_centre  [499.25 314.25]
# robot_heading  -62.96913974015701
# target_vector  [ 89.75 -40.75]
# target_angle  114.41990113803742
# heading_error  177.38904087819446
# absHeadingError  2.6109591218055357
# PWM1  169.26298867842613 PWM2  170.30737232714833 mode  2
# 169.26298867842613,170.30737232714833,2
# 291.7355394873926
# rotationDirection  -1
# target_centre  [591.5 273. ]
# robot_centre  [502.75 312.75]
# robot_heading  -63.92464441605123
# target_vector  [ 88.75 -39.75]
# target_angle  114.1270026374922
# heading_error  178.05164705354343
# absHeadingError  1.9483529464565663
# PWM1  169.58677697436963 PWM2  169.58677697436963 mode  2
# 169.58677697436963,169.58677697436963,2
# 293.7904227506404
# rotationDirection  -1
# target_centre  [595.  271.5]
# robot_centre  [505.5  311.25]
# robot_heading  -62.487997376148556
# target_vector  [ 89.5  -39.75]
# target_angle  113.94763781381356
# heading_error  176.4356351899621
# absHeadingError  3.564364810037887
# PWM1  168.97664817552445 PWM2  170.40239409953958 mode  2
# 168.97664817552445,170.40239409953958,2
# 288.1601117434542
# rotationDirection  -1
# target_centre  [596.5 271.5]
# robot_centre  [508.5 310. ]
# robot_heading  -61.55707137563666
# target_vector  [ 88.  -38.5]
# target_angle  113.62937773065681
# heading_error  175.18644910629348
# absHeadingError  4.81355089370652
# PWM1  168.4452954084314 PWM2  170.370715765914 mode  2
# 168.4452954084314,170.370715765914,2
# 286.7865059587009
# rotationDirection  -1
# target_centre  [599. 270.]
# robot_centre  [511.5 308.5]
# robot_heading  -61.55707137563666
# target_vector  [ 87.5 -38.5]
# target_angle  113.74949449286676
# heading_error  175.3065658685034
# absHeadingError  4.693434131496588
# PWM1  168.40063847163572 PWM2  170.27801212423435 mode  2
# 168.40063847163572,170.27801212423435,2
# target_centre  [602.5 269. ]
# robot_centre  [514.5 307. ]
# robot_heading  -61.55707137563666
# target_vector  [ 88. -38.]
# target_angle  113.355564859286
# heading_error  174.91263623492267
# absHeadingError  5.087363765077328
# PWM1  155.28263132028206 PWM2  155.28263132028206 mode  -1
# 155.28263132028206,155.28263132028206,-1
# target_centre  [604.5 269. ]
# robot_centre  [517.25 305.25]
# robot_heading  -61.99082329198616
# target_vector  [ 87.25 -36.25]
# target_angle  112.56155458804439
# heading_error  174.55237788003058
# absHeadingError  5.447622119969424
# PWM1  155.30264567333163 PWM2  155.30264567333163 mode  -1
# 155.30264567333163,155.30264567333163,-1
# target_centre  [607.5 268. ]
# robot_centre  [520.25 304.25]
# robot_heading  -60.94539590092286
# target_vector  [ 87.25 -36.25]
# target_angle  112.56155458804439
# heading_error  173.50695048896728
# absHeadingError  6.493049511032723
# PWM1  155.36072497283516 PWM2  155.36072497283516 mode  -1
# 155.36072497283516,155.36072497283516,-1
# target_centre  [610.  267.5]
# robot_centre  [522.5  302.75]
# robot_heading  -61.476881393687975
# target_vector  [ 87.5  -35.25]
# target_angle  111.94239291124664
# heading_error  173.41927430493462
# absHeadingError  6.580725695065382
# PWM1  155.36559587194807 PWM2  155.36559587194807 mode  -1
# 155.36559587194807,155.36559587194807,-1
# target_centre  [612.5 267. ]
# robot_centre  [525.   301.25]
# robot_heading  -61.476881393687975
# target_vector  [ 87.5  -34.25]
# target_angle  111.37679438819393
# heading_error  172.85367578188192
# absHeadingError  7.146324218118082
# PWM1  155.39701801211768 PWM2  155.39701801211768 mode  -1
# 155.39701801211768,155.39701801211768,-1
# target_centre  [614.  267.5]
# robot_centre  [526.5 300.5]
# robot_heading  -61.55707137563666
# target_vector  [ 87.5 -33. ]
# target_angle  110.66360913485548
# heading_error  172.22068051049212
# absHeadingError  7.779319489507884
# PWM1  155.43218441608377 PWM2  155.43218441608377 mode  -1
# 155.43218441608377,155.43218441608377,-1
# 279.8716223556794
# rotationDirection  -1
# target_centre  [615.5 267. ]
# robot_centre  [526.75 295.75]
# robot_heading  -67.61986494804043
# target_vector  [ 88.75 -28.75]
# target_angle  107.94940299291389
# heading_error  175.56926794095432
# absHeadingError  4.430732059045681
# PWM1  168.10743470597484 PWM2  169.8797275295931 mode  2
# 168.10743470597484,169.8797275295931,2
# 280.39369643413886
# rotationDirection  -1
# target_centre  [615.5 267. ]
# robot_centre  [526.25 294.75]
# robot_heading  -71.56505117707799
# target_vector  [ 89.25 -27.75]
# target_angle  107.27174257768088
# heading_error  178.8367937547589
# absHeadingError  1.1632062452410992
# PWM1  169.01968482170693 PWM2  169.01968482170693 mode  2
# 169.01968482170693,169.01968482170693,2
# 279.8103152137176
# rotationDirection  1
# target_centre  [615.5 267. ]
# robot_centre  [526.   293.25]
# robot_heading  -73.90918365114783
# target_vector  [ 89.5  -26.25]
# target_angle  106.34620667151138
# heading_error  -179.7446096773408
# absHeadingError  0.2553903226591956
# PWM1  168.99051576068587 PWM2  168.99051576068587 mode  2
# 168.99051576068587,168.99051576068587,2
# 280.0233249213358
# rotationDirection  -1
# target_centre  [615.5 267. ]
# robot_centre  [525.5  291.75]
# robot_heading  -73.90918365114783
# target_vector  [ 90.   -24.75]
# target_angle  105.3762512488262
# heading_error  179.285434899974
# absHeadingError  0.7145651000259932
# PWM1  169.0011662460668 PWM2  169.0011662460668 mode  2
# 169.0011662460668,169.0011662460668,2
# 280.5040106665144
# rotationDirection  1
# target_centre  [615.5 267. ]
# robot_centre  [525.  290.5]
# robot_heading  -77.47119229084849
# target_vector  [ 90.5 -23.5]
# target_angle  104.55642432007431
# heading_error  -177.9723833890772
# absHeadingError  2.0276166109227916
# PWM1  169.43072385551028 PWM2  168.61967721114115 mode  2
# 169.43072385551028,168.61967721114115,2
# 279.23075135092125
# rotationDirection  1
# target_centre  [615.5 267. ]
# robot_centre  [525.   288.75]
# robot_heading  -80.53767779197439
# target_vector  [ 90.5  -21.75]
# target_angle  103.51369058678318
# heading_error  -175.94863162124244
# absHeadingError  4.051368378757559
# PWM1  169.77181124329758 PWM2  168.15126389179454 mode  2
# 169.77181124329758,168.15126389179454,2
# 280.4097448377998
# rotationDirection  1
# target_centre  [615.5 267.5]
# robot_centre  [524.25 287.75]
# robot_heading  -82.47617956136138
# target_vector  [ 91.25 -20.25]
# target_angle  102.51218578344636
# heading_error  -175.01163465519227
# absHeadingError  4.9883653448077325
# PWM1  170.01816031085153 PWM2  168.02281417292843 mode  2
# 170.01816031085153,168.02281417292843,2
# target_centre  [616. 267.]
# robot_centre  [524.  286.5]
# robot_heading  -83.6598082540901
# target_vector  [ 92.  -19.5]
# target_angle  101.96710237658496
# heading_error  -174.37308936932493
# absHeadingError  5.62691063067507
# PWM1  155.31260614614862 PWM2  155.31260614614862 mode  1
# 155.31260614614862,155.31260614614862,1
# target_centre  [616.  267.5]
# robot_centre  [525.   285.25]
# robot_heading  -86.82016988013577
# target_vector  [ 91.   -17.75]
# target_angle  101.03724176956764
# heading_error  -172.1425883502966
# absHeadingError  7.857411649703408
# PWM1  155.43652286942796 PWM2  155.43652286942796 mode  1
# 155.43652286942796,155.43652286942796,1
# target_centre  [474.5 186. ]
# robot_centre  [540. 287.]
# robot_heading  -81.2538377374448
# target_vector  [ -65.5 -101. ]
# target_angle  -147.0359921955531
# heading_error  -65.7821544581083
# absHeadingError  65.7821544581083
# PWM1  158.65456413656156 PWM2  158.65456413656156 mode  -1
# 158.65456413656156,158.65456413656156,-1
# target_centre  [475. 184.]
# robot_centre  [540. 287.]
# robot_heading  -81.2538377374448
# target_vector  [ -65. -103.]
# target_angle  -147.74528947313286
# heading_error  -66.49145173568806
# absHeadingError  66.49145173568806
# PWM1  158.69396954087156 PWM2  158.69396954087156 mode  -1
# 158.69396954087156,158.69396954087156,-1
# target_centre  [475.5 182.5]
# robot_centre  [540. 287.]
# robot_heading  -81.2538377374448
# target_vector  [ -64.5 -104.5]
# target_angle  -148.31608304910728
# heading_error  -67.06224531166248
# absHeadingError  67.06224531166248
# PWM1  158.72568029509236 PWM2  158.72568029509236 mode  -1
# 158.72568029509236,158.72568029509236,-1
# target_centre  [475.5 181.5]
# robot_centre  [540.   286.75]
# robot_heading  -82.33319573818582
# target_vector  [ -64.5  -105.25]
# target_angle  -148.49892471283803
# heading_error  -66.16572897465221
# absHeadingError  66.16572897465221
# PWM1  158.67587383192512 PWM2  158.67587383192512 mode  -1
# 158.67587383192512,158.67587383192512,-1
# target_centre  [475.5 181.5]
# robot_centre  [540.   286.75]
# robot_heading  -82.33319573818582
# target_vector  [ -64.5  -105.25]
# target_angle  -148.49892471283803
# heading_error  -66.16572897465221
# absHeadingError  66.16572897465221
# PWM1  158.67587383192512 PWM2  158.67587383192512 mode  -1
# 158.67587383192512,158.67587383192512,-1
# target_centre  [475.5 181.5]
# robot_centre  [539.75 286.5 ]
# robot_heading  -81.41637851988605
# target_vector  [ -64.25 -105.  ]
# target_angle  -148.537337760646
# heading_error  -67.12095924075996
# absHeadingError  67.12095924075996
# PWM1  158.72894218004222 PWM2  158.72894218004222 mode  -1
# 158.72894218004222,158.72894218004222,-1
# target_centre  [475.5 181.5]
# robot_centre  [539.5 285. ]
# robot_heading  -83.418055344822
# target_vector  [ -64.  -103.5]
# target_angle  -148.26911537755083
# heading_error  -64.85106003272884
# absHeadingError  64.85106003272884
# PWM1  158.60283666848494 PWM2  158.60283666848494 mode  -1
# 158.60283666848494,158.60283666848494,-1
# target_centre  [475.5 181.5]
# robot_centre  [539.25 284.  ]
# robot_heading  -85.68397248013439
# target_vector  [ -63.75 -102.5 ]
# target_angle  -148.12040315297727
# heading_error  -62.43643067284289
# absHeadingError  62.43643067284289
# PWM1  158.46869059293573 PWM2  158.46869059293573 mode  -1
# 158.46869059293573,158.46869059293573,-1
# target_centre  [475.5 181.5]
# robot_centre  [539.  282.5]
# robot_heading  -87.87890360333854
# target_vector  [ -63.5 -101. ]
# target_angle  -147.84189628417215
# heading_error  -59.96299268083361
# absHeadingError  59.96299268083361
# PWM1  158.33127737115743 PWM2  158.33127737115743 mode  -1
# 158.33127737115743,158.33127737115743,-1
# target_centre  [475.5 181.5]
# robot_centre  [538.75 281.  ]
# robot_heading  -90.0
# target_vector  [-63.25 -99.5 ]
# target_angle  -147.55676141298972
# heading_error  -57.556761412989715
# absHeadingError  57.556761412989715
# PWM1  158.1975978562772 PWM2  158.1975978562772 mode  -1
# 158.1975978562772,158.1975978562772,-1
# target_centre  [475.5 181.5]
# robot_centre  [538.75 279.  ]
# robot_heading  -92.16107948822638
# target_vector  [-63.25 -97.5 ]
# target_angle  -147.02780145311442
# heading_error  -54.86672196488804
# absHeadingError  54.86672196488804
# PWM1  158.04815122027156 PWM2  158.04815122027156 mode  -1
# 158.04815122027156,158.04815122027156,-1
# target_centre  [475.5 181.5]
# robot_centre  [538.5 277.5]
# robot_heading  -96.3401917459099
# target_vector  [-63. -96.]
# target_angle  -146.72511201516508
# heading_error  -50.38492026925519
# absHeadingError  50.38492026925519
# PWM1  157.79916223718084 PWM2  157.79916223718084 mode  -1
# 157.79916223718084,157.79916223718084,-1
# target_centre  [475.5 181.5]
# robot_centre  [538.5  274.25]
# robot_heading  -101.94417718844633
# target_vector  [-63.   -92.75]
# target_angle  -145.813877513625
# heading_error  -43.869700325178655
# absHeadingError  43.869700325178655
# PWM1  157.43720557362104 PWM2  157.43720557362104 mode  -1
# 157.43720557362104,157.43720557362104,-1
# target_centre  [475.5 181.5]
# robot_centre  [538.5 272.5]
# robot_heading  -105.06848815949222
# target_vector  [-63. -91.]
# target_angle  -145.30484646876604
# heading_error  -40.23635830927384
# absHeadingError  40.23635830927384
# PWM1  157.2353532394041 PWM2  157.2353532394041 mode  -1
# 157.2353532394041,157.2353532394041,-1
# target_centre  [475.5 181.5]
# robot_centre  [539.  270.5]
# robot_heading  -107.74467162505692
# target_vector  [-63.5 -89. ]
# target_angle  -144.49278248134576
# heading_error  -36.74811085628883
# absHeadingError  36.74811085628883
# PWM1  157.04156171423827 PWM2  157.04156171423827 mode  -1
# 157.04156171423827,157.04156171423827,-1
# target_centre  [475.5 181.5]
# robot_centre  [538.75 269.  ]
# robot_heading  -112.2034785320574
# target_vector  [-63.25 -87.5 ]
# target_angle  -144.13844641950845
# heading_error  -31.93496788745105
# absHeadingError  31.93496788745105
# PWM1  156.77416488263617 PWM2  156.77416488263617 mode  -1
# 156.77416488263617,156.77416488263617,-1
# target_centre  [475.5 181.5]
# robot_centre  [538.75 269.  ]
# robot_heading  -112.2034785320574
# target_vector  [-63.25 -87.5 ]
# target_angle  -144.13844641950845
# heading_error  -31.93496788745105
# absHeadingError  31.93496788745105
# PWM1  156.77416488263617 PWM2  156.77416488263617 mode  -1
# 156.77416488263617,156.77416488263617,-1
# target_centre  [475.5 181.5]
# robot_centre  [539.5 267. ]
# robot_heading  -114.62356478616361
# target_vector  [-64.  -85.5]
# target_angle  -143.1837500721046
# heading_error  -28.560185285940975
# absHeadingError  28.560185285940975
# PWM1  156.58667696033007 PWM2  156.58667696033007 mode  -1
# 156.58667696033007,156.58667696033007,-1
# target_centre  [475.5 181.5]
# robot_centre  [539.5 265.5]
# robot_heading  -116.56505117707799
# target_vector  [-64. -84.]
# target_angle  -142.6960517220166
# heading_error  -26.131000544938615
# absHeadingError  26.131000544938615
# PWM1  156.45172225249658 PWM2  156.45172225249658 mode  -1
# 156.45172225249658,156.45172225249658,-1
# target_centre  [475.5 181.5]
# robot_centre  [540.75 263.75]
# robot_heading  -120.96375653207352
# target_vector  [-65.25 -82.25]
# target_angle  -141.5745725785958
# heading_error  -20.610816046522274
# absHeadingError  20.610816046522274
# PWM1  156.1450453359179 PWM2  156.1450453359179 mode  -1
# 156.1450453359179,156.1450453359179,-1
# target_centre  [475.5 181.5]
# robot_centre  [540.75 262.75]
# robot_heading  -122.79953127261923
# target_vector  [-65.25 -81.25]
# target_angle  -141.23285620359619
# heading_error  -18.433324930976937
# absHeadingError  18.433324930976937
# PWM1  156.0240736072765 PWM2  156.0240736072765 mode  -1
# 156.0240736072765,156.0240736072765,-1
# target_centre  [475.5 181.5]
# robot_centre  [541.5  260.25]
# robot_heading  -125.1664360357929
# target_vector  [-66.   -78.75]
# target_angle  -140.03378695620006
# heading_error  -14.867350920407148
# absHeadingError  14.867350920407148
# PWM1  155.82596394002263 PWM2  155.82596394002263 mode  -1
# 155.82596394002263,155.82596394002263,-1
# target_centre  [475.5 181.5]
# robot_centre  [542.5 259. ]
# robot_heading  -126.02737338510362
# target_vector  [-67.  -77.5]
# target_angle  -139.15605660127642
# heading_error  -13.128683216172817
# absHeadingError  13.128683216172817
# PWM1  155.72937128978737 PWM2  155.72937128978737 mode  -1
# 155.72937128978737,155.72937128978737,-1
# 306.3867041828023
# rotationDirection  -1
# target_centre  [475.5 181.5]
# robot_centre  [544.   257.25]
# robot_heading  -134.23610153907
# target_vector  [-68.5  -75.75]
# target_angle  -137.8772628053914
# heading_error  -3.6411612663214044
# absHeadingError  3.6411612663214044
# PWM1  171.0475674624044 PWM2  169.59110295587584 mode  0
# 171.0475674624044,169.59110295587584,0
# 303.5341825890455
# rotationDirection  -1
# target_centre  [475.5 181.5]
# robot_centre  [544.5 255.5]
# robot_heading  -135.0
# target_vector  [-69. -74.]
# target_angle  -137.00253313182688
# heading_error  -2.0025331318268798
# absHeadingError  2.0025331318268798
# PWM1  170.57721575581763 PWM2  169.7762025030869 mode  0
# 170.57721575581763,169.7762025030869,0
# 304.47598427462225
# rotationDirection  1
# target_centre  [475.5 181.5]
# robot_centre  [545.75 254.75]
# robot_heading  -138.0940580589171
# target_vector  [-70.25 -73.25]
# target_angle  -136.1976467146084
# heading_error  1.8964113443087172
# absHeadingError  1.8964113443087172
# PWM1  170.22379921373113 PWM2  170.22379921373113 mode  0
# 170.22379921373113,170.22379921373113,0
# 303.89070815015054
# rotationDirection  1
# target_centre  [475.5 181.5]
# robot_centre  [546.5  253.75]
# robot_heading  -138.71528910542878
# target_vector  [-71.   -72.25]
# target_angle  -135.49995048300804
# heading_error  3.215338622420745
# absHeadingError  3.215338622420745
# PWM1  169.55146768302336 PWM2  170.83760313199167 mode  0
# 169.55146768302336,170.83760313199167,0
# target_centre  [475.5 181.5]
# robot_centre  [546.5  253.25]
# robot_heading  -142.02839623894963
# target_vector  [-71.   -71.75]
# target_angle  -135.3010258440964
# heading_error  6.727370394853239
# absHeadingError  6.727370394853239
# PWM1  155.37374279971408 PWM2  155.37374279971408 mode  1
# 155.37374279971408,155.37374279971408,1
# target_centre  [475.5 181.5]
# robot_centre  [546.5  253.25]
# robot_heading  -142.02839623894963
# target_vector  [-71.   -71.75]
# target_angle  -135.3010258440964
# heading_error  6.727370394853239
# absHeadingError  6.727370394853239
# PWM1  155.37374279971408 PWM2  155.37374279971408 mode  1
# 155.37374279971408,155.37374279971408,1
# target_centre  [475.5 181.5]
# robot_centre  [545.75 251.5 ]
# robot_heading  -141.84277341263095
# target_vector  [-70.25 -70.  ]
# target_angle  -134.89786859388772
# heading_error  6.944904818743225
# absHeadingError  6.944904818743225
# PWM1  155.38582804548574 PWM2  155.38582804548574 mode  1
# 155.38582804548574,155.38582804548574,1
# target_centre  [475.5 181.5]
# robot_centre  [544.25 249.5 ]
# robot_heading  -141.84277341263095
# target_vector  [-68.75 -68.  ]
# target_angle  -134.68576669990333
# heading_error  7.157006712727622
# absHeadingError  7.157006712727622
# PWM1  155.39761148404043 PWM2  155.39761148404043 mode  1
# 155.39761148404043,155.39761148404043,1
# target_centre  [475.5 181.5]
# robot_centre  [543.   247.75]
# robot_heading  -142.02839623894963
# target_vector  [-67.5  -66.25]
# target_angle  -134.46454101443547
# heading_error  7.563855224514157
# absHeadingError  7.563855224514157
# PWM1  155.42021417913966 PWM2  155.42021417913966 mode  1
# 155.42021417913966,155.42021417913966,1
# target_centre  [475.5 181.5]
# robot_centre  [541.5 245.5]
# robot_heading  -142.6960517220166
# target_vector  [-66. -64.]
# target_angle  -134.11859600341788
# heading_error  8.577455718598713
# absHeadingError  8.577455718598713
# PWM1  155.47652531769992 PWM2  155.47652531769992 mode  1
# 155.47652531769992,155.47652531769992,1
# target_centre  [475.5 181.5]
# robot_centre  [539.5 243.5]
# robot_heading  -142.6960517220166
# target_vector  [-64. -62.]
# target_angle  -134.09061955080085
# heading_error  8.605432171215739
# absHeadingError  8.605432171215739
# PWM1  155.47807956506753 PWM2  155.47807956506753 mode  1
# 155.47807956506753,155.47807956506753,1
# target_centre  [475.5 181.5]
# robot_centre  [538.5  243.25]
# robot_heading  -142.02839623894963
# target_vector  [-63.   -61.75]
# target_angle  -134.42591320534217
# heading_error  7.602483033607456
# absHeadingError  7.602483033607456
# PWM1  155.42236016853374 PWM2  155.42236016853374 mode  1
# 155.42236016853374,155.42236016853374,1
# 260.3926122223901
# rotationDirection  1
# target_centre  [475.5 181.5]
# robot_centre  [536.75 243.  ]
# robot_heading  -138.81407483429035
# target_vector  [-61.25 -61.5 ]
# target_angle  -135.11669185395647
# heading_error  3.6973829803338845
# absHeadingError  3.6973829803338845
# PWM1  167.28015401505274 PWM2  168.75910720718628 mode  0
# 167.28015401505274,168.75910720718628,0
# 258.3932323030152
# rotationDirection  -1
# target_centre  [475.5 181.5]
# robot_centre  [534.5  244.25]
# robot_heading  -134.23610153907
# target_vector  [-59.   -62.75]
# target_angle  -136.76419931715884
# heading_error  -2.528097778088835
# absHeadingError  2.528097778088835
# PWM1  168.42528117076853 PWM2  167.41404205953302 mode  0
# 168.42528117076853,167.41404205953302,0
# 258.00436042826874
# rotationDirection  -1
# target_centre  [475.5 181.5]
# robot_centre  [533.5 245. ]
# robot_heading  -133.45184230102205
# target_vector  [-58.  -63.5]
# target_angle  -137.59186670523502
# heading_error  -4.140024404212966
# absHeadingError  4.140024404212966
# PWM1  168.72822290225602 PWM2  167.07221314057082 mode  0
# 168.72822290225602,167.07221314057082,0
# target_centre  [475.5 181.5]
# robot_centre  [532.25 246.5 ]
# robot_heading  -129.66784111834045
# target_vector  [-56.75 -65.  ]
# target_angle  -138.8765395459972
# heading_error  -9.208698427656742
# absHeadingError  9.208698427656742
# PWM1  155.51159435709204 PWM2  155.51159435709204 mode  -1
# 155.51159435709204,155.51159435709204,-1
# target_centre  [475.5 181.5]
# robot_centre  [531.   247.75]
# robot_heading  -128.15722658736905
# target_vector  [-55.5  -66.25]
# target_angle  -140.04588462699704
# heading_error  -11.888658039627984
# absHeadingError  11.888658039627984
# PWM1  155.66048100220155 PWM2  155.66048100220155 mode  -1
# 155.66048100220155,155.66048100220155,-1
# target_centre  [475.5 181.5]
# robot_centre  [530.25 248.75]
# robot_heading  -125.78897345918334
# target_vector  [-54.75 -67.25]
# target_angle  -140.85005520571738
# heading_error  -15.061081746534057
# absHeadingError  15.061081746534057
# PWM1  155.83672676369633 PWM2  155.83672676369633 mode  -1
# 155.83672676369633,155.83672676369633,-1
# target_centre  [475.5 181.5]
# robot_centre  [517.5  245.75]
# robot_heading  -120.41108126712537
# target_vector  [-42.   -64.25]
# target_angle  -146.8274954468458
# heading_error  -26.416414179720448
# absHeadingError  26.416414179720448
# PWM1  156.46757856554004 PWM2  156.46757856554004 mode  -1
# 156.46757856554004,156.46757856554004,-1
# target_centre  [475.5 181.5]
# robot_centre  [515.25 243.  ]
# robot_heading  -121.89079180184572
# target_vector  [-39.75 -61.5 ]
# target_angle  -147.1237382477894
# heading_error  -25.232946445943668
# absHeadingError  25.232946445943668
# PWM1  156.401830358108 PWM2  156.401830358108 mode  -1
# 156.401830358108,156.401830358108,-1
# target_centre  [475.5 181.5]
# robot_centre  [513.75 242.  ]
# robot_heading  -121.89079180184572
# target_vector  [-38.25 -60.5 ]
# target_angle  -147.69764021664983
# heading_error  -25.806848414804108
# absHeadingError  25.806848414804108
# PWM1  156.43371380082246 PWM2  156.43371380082246 mode  -1
# 156.43371380082246,156.43371380082246,-1
# target_centre  [475.5 181.5]
# robot_centre  [514.   240.25]
# robot_heading  -126.43085812016236
# target_vector  [-38.5  -58.75]
# target_angle  -146.76240701237055
# heading_error  -20.33154889220819
# absHeadingError  20.33154889220819
# PWM1  156.12953049401156 PWM2  156.12953049401156 mode  -1
# 156.12953049401156,156.12953049401156,-1
# target_centre  [475.5 181.5]
# robot_centre  [514.5  238.25]
# robot_heading  -128.15722658736905
# target_vector  [-39.   -56.75]
# target_angle  -145.50219050874995
# heading_error  -17.344963921380895
# absHeadingError  17.344963921380895
# PWM1  155.96360910674338 PWM2  155.96360910674338 mode  -1
# 155.96360910674338,155.96360910674338,-1
# target_centre  [475.5 181.5]
# robot_centre  [514.25 237.25]
# robot_heading  -130.48601154199872
# target_vector  [-38.75 -55.75]
# target_angle  -145.1981008456234
# heading_error  -14.71208930362468
# absHeadingError  14.71208930362468
# PWM1  155.81733829464582 PWM2  155.81733829464582 mode  -1
# 155.81733829464582,155.81733829464582,-1
# target_centre  [475.5 181.5]
# robot_centre  [514.25 237.25]
# robot_heading  -130.48601154199872
# target_vector  [-38.75 -55.75]
# target_angle  -145.1981008456234
# heading_error  -14.71208930362468
# absHeadingError  14.71208930362468
# PWM1  155.81733829464582 PWM2  155.81733829464582 mode  -1
# 155.81733829464582,155.81733829464582,-1
# target_centre  [475.5 181.5]
# robot_centre  [514.75 235.5 ]
# robot_heading  -131.08175113593262
# target_vector  [-39.25 -54.  ]
# target_angle  -143.9884018841875
# heading_error  -12.90665074825489
# absHeadingError  12.90665074825489
# PWM1  155.71703615268083 PWM2  155.71703615268083 mode  -1
# 155.71703615268083,155.71703615268083,-1
# target_centre  [476.  181.5]
# robot_centre  [516. 234.]
# robot_heading  -135.0
# target_vector  [-40.  -52.5]
# target_angle  -142.6960517220166
# heading_error  -7.696051722016591
# absHeadingError  7.696051722016591
# PWM1  155.42755842900092 PWM2  155.42755842900092 mode  -1
# 155.42755842900092,155.42755842900092,-1
# 195.25656198960382
# rotationDirection  -1
# target_centre  [476.  181.5]
# robot_centre  [516.75 232.25]
# robot_heading  -137.9356734464212
# target_vector  [-40.75 -50.75]
# target_angle  -141.2370800764585
# heading_error  -3.30140663003732
# absHeadingError  3.30140663003732
# PWM1  165.42310942548767 PWM2  164.10254677347274 mode  0
# 165.42310942548767,164.10254677347274,0
# 193.78467431662392
# rotationDirection  1
# target_centre  [476.  181.5]
# robot_centre  [517.5 231. ]
# robot_heading  -141.34019174590992
# target_vector  [-41.5 -49.5]
# target_angle  -140.02407525853954
# heading_error  1.3161164873703797
# absHeadingError  1.3161164873703797
# PWM1  164.6892337158312 PWM2  164.6892337158312 mode  0
# 164.6892337158312,164.6892337158312,0
# target_centre  [475.5 181.5]
# robot_centre  [518.5 230. ]
# robot_heading  -143.9726266148964
# target_vector  [-43.  -48.5]
# target_angle  -138.43986969374603
# heading_error  5.532756921150366
# absHeadingError  5.532756921150366
# PWM1  155.30737538450836 PWM2  155.30737538450836 mode  1
# 155.30737538450836,155.30737538450836,1
# target_centre  [476. 182.]
# robot_centre  [520.   228.25]
# robot_heading  -148.1092081981543
# target_vector  [-44.   -46.25]
# target_angle  -136.42813080390155
# heading_error  11.681077394252753
# absHeadingError  11.681077394252753
# PWM1  155.64894874412516 PWM2  155.64894874412516 mode  1
# 155.64894874412516,155.64894874412516,1
# target_centre  [476. 182.]
# robot_centre  [520.75 227.5 ]
# robot_heading  -149.58891873287465
# target_vector  [-44.75 -45.5 ]
# target_angle  -135.47613125164187
# heading_error  14.112787481232772
# absHeadingError  14.112787481232772
# PWM1  155.78404374895737 PWM2  155.78404374895737 mode  1
# 155.78404374895737,155.78404374895737,1
# target_centre  [476. 182.]
# robot_centre  [520.75 227.25]
# robot_heading  -149.03624346792648
# target_vector  [-44.75 -45.25]
# target_angle  -135.3183066114514
# heading_error  13.717936856475092
# absHeadingError  13.717936856475092
# PWM1  155.7621076031375 PWM2  155.7621076031375 mode  1
# 155.7621076031375,155.7621076031375,1
# target_centre  [475.5 181.5]
# robot_centre  [520. 227.]
# robot_heading  -148.67130713219584
# ...
# robot_heading  110.80679101271124
# target_vector  [212.5  -37.25]
# target_angle  99.9425956416167
# heading_error  -10.864195371094524
# absHeadingError  10.864195371094524
# PWM1  155.60356640950525 PWM2  155.60356640950525 mode  -1
# 155.60356640950525,155.60356640950525,-1
# target_centre  [587.  178.5]
# robot_centre  [374.25 214.25]
# robot_heading  111.19405648154229
# target_vector  [212.75 -35.75]
# target_angle  99.53873108949445
# heading_error  -11.655325392047843
# absHeadingError  11.655325392047843
# PWM1  155.647518077336 PWM2  155.647518077336 mode  -1
# 155.647518077336,155.647518077336,-1
# target_centre  [587.  178.5]
# robot_centre  [375.   212.25]
# robot_heading  114.7024302277713
# target_vector  [212.   -33.75]
# target_angle  99.04547342251547
# heading_error  -15.656956805255845
# absHeadingError  15.656956805255845
# PWM1  155.86983093362534 PWM2  155.86983093362534 mode  -1
# 155.86983093362534,155.86983093362534,-1
# target_centre  [587.5 178. ]
# robot_centre  [377.  210.5]
# robot_heading  117.47443162627712
# target_vector  [210.5 -32.5]
# target_angle  98.77683999272004
# heading_error  -18.697591633557067
# absHeadingError  18.697591633557067
# PWM1  156.03875509075317 PWM2  156.03875509075317 mode  -1
# 156.03875509075317,156.03875509075317,-1
# target_centre  [587.5 178. ]
# robot_centre  [378.75 209.75]
# robot_heading  115.14478563067895
# target_vector  [208.75 -31.75]
# target_angle  98.64816795620276
# heading_error  -16.496617674476198
# absHeadingError  16.496617674476198
# PWM1  155.91647875969312 PWM2  155.91647875969312 mode  -1
# 155.91647875969312,155.91647875969312,-1
# target_centre  [587.5 177.5]
# robot_centre  [380.  209.5]
# robot_heading  115.64100582430528
# target_vector  [207.5 -32. ]
# target_angle  98.76691032592969
# heading_error  -16.874095498375596
# absHeadingError  16.874095498375596
# PWM1  155.93744974990975 PWM2  155.93744974990975 mode  -1
# 155.93744974990975,155.93744974990975,-1
# target_centre  [588. 178.]
# robot_centre  [380.75 209.75]
# robot_heading  112.38013505195958
# target_vector  [207.25 -31.75]
# target_angle  98.70980378165987
# heading_error  -13.670331270299698
# absHeadingError  13.670331270299698
# PWM1  155.75946284834998 PWM2  155.75946284834998 mode  -1
# 155.75946284834998,155.75946284834998,-1
# target_centre  [588. 178.]
# robot_centre  [381.5  210.75]
# robot_heading  112.7824057304817
# target_vector  [206.5  -32.75]
# target_angle  99.01180442781474
# heading_error  -13.770601302666961
# absHeadingError  13.770601302666961
# PWM1  155.76503340570372 PWM2  155.76503340570372 mode  -1
# 155.76503340570372,155.76503340570372,-1
# target_centre  [589.5 177.5]
# robot_centre  [383.5 214. ]
# robot_heading  107.10272896905236
# target_vector  [206.  -36.5]
# target_angle  100.04764183270349
# heading_error  -7.055087136348874
# absHeadingError  7.055087136348874
# PWM1  155.39194928535272 PWM2  155.39194928535272 mode  -1
# 155.39194928535272,155.39194928535272,-1
# target_centre  [583.5 174. ]
# robot_centre  [385.   218.25]
# robot_heading  97.38604315126727
# target_vector  [198.5  -44.25]
# target_angle  102.56700488983473
# heading_error  5.1809617385674755
# absHeadingError  5.1809617385674755
# PWM1  155.2878312076982 PWM2  155.2878312076982 mode  1
# 155.2878312076982,155.2878312076982,1
# target_centre  [579. 174.]
# robot_centre  [385.   218.25]
# robot_heading  97.38604315126727
# target_vector  [194.   -44.25]
# target_angle  102.84893615219765
# heading_error  5.4628930009303645
# absHeadingError  5.4628930009303645
# PWM1  155.30349405560725 PWM2  155.30349405560725 mode  1
# 155.30349405560725,155.30349405560725,1
# target_centre  [573.5 174. ]
# robot_centre  [385.   218.25]
# robot_heading  97.38604315126727
# target_vector  [188.5  -44.25]
# target_angle  103.21086810232417
# heading_error  5.824824951056883
# absHeadingError  5.824824951056883
# PWM1  155.32360138616983 PWM2  155.32360138616983 mode  1
# 155.32360138616983,155.32360138616983,1
# target_centre  [569.  174.5]
# robot_centre  [385.   218.25]
# robot_heading  97.38604315126727
# target_vector  [184.   -43.75]
# target_angle  103.37495572395414
# heading_error  5.988912572686871
# absHeadingError  5.988912572686871
# PWM1  155.33271736514928 PWM2  155.33271736514928 mode  1
# 155.33271736514928,155.33271736514928,1
# 554.505184826977
# rotationDirection  1
# target_centre  [565.  175.5]
# robot_centre  [385.  217.5]
# robot_heading  100.4914770123316
# target_vector  [180. -42.]
# target_angle  103.13402230639633
# heading_error  2.642545294064746
# absHeadingError  2.642545294064746
# PWM1  182.1967501825359 PWM2  183.2537683001618 mode  0
# 182.1967501825359,183.2537683001618,0
# 544.4989669411688
# rotationDirection  1
# target_centre  [561.5 175.5]
# robot_centre  [384.75 216.75]
# robot_heading  99.63753811293094
# target_vector  [176.75 -41.25]
# target_angle  103.13658415658523
# heading_error  3.499046043654289
# absHeadingError  3.499046043654289
# PWM1  181.52513913832757 PWM2  182.9247575557893 mode  0
# 181.52513913832757,182.9247575557893,0
# 535.2814680147259
# rotationDirection  1
# target_centre  [558.5 176. ]
# robot_centre  [384.5 215.5]
# robot_heading  102.52880770915151
# target_vector  [174.  -39.5]
# target_angle  102.79003285740339
# heading_error  0.26122514825186727
# absHeadingError  0.26122514825186727
# PWM1  181.7640734007363 PWM2  181.7640734007363 mode  0
# 181.7640734007363,181.7640734007363,0
# 524.3782032083332
# rotationDirection  -1
# target_centre  [554.5 176.5]
# robot_centre  [384. 215.]
# robot_heading  104.53445508054013
# target_vector  [170.5 -38.5]
# target_angle  102.72435568542238
# heading_error  -1.8100993951177315
# absHeadingError  1.8100993951177315
# PWM1  181.21891016041667 PWM2  181.21891016041667 mode  0
# 181.21891016041667,181.21891016041667,0
# 513.3118569641656
# rotationDirection  -1
# target_centre  [551.5 176.5]
# robot_centre  [384.5  213.75]
# robot_heading  105.52411099675426
# target_vector  [167.   -37.25]
# target_angle  102.57420847580867
# heading_error  -2.949902520945585
# absHeadingError  2.949902520945585
# PWM1  181.25557335239742 PWM2  180.07561234401916 mode  0
# 181.25557335239742,180.07561234401916,0
# 500.6231741539738
# rotationDirection  -1
# target_centre  [549.5 176.5]
# robot_centre  [386.5  212.25]
# robot_heading  106.09081634885217
# target_vector  [163.   -35.75]
# target_angle  102.37053247773738
# heading_error  -3.7202838711147876
# absHeadingError  3.7202838711147876
# PWM1  180.77521548192166 PWM2  179.28710193347572 mode  0
# 180.77521548192166,179.28710193347572,0
# target_centre  [548.  176.5]
# robot_centre  [388.75 210.75]
# robot_heading  107.78388844269253
# target_vector  [159.25 -34.25]
# target_angle  102.13774886405477
# heading_error  -5.646139578637758
# absHeadingError  5.646139578637758
# PWM1  155.31367442103544 PWM2  155.31367442103544 mode  -1
# 155.31367442103544,155.31367442103544,-1
# target_centre  [546.5 177. ]
# robot_centre  [392.  209.5]
# robot_heading  107.10272896905236
# target_vector  [154.5 -32.5]
# target_angle  101.879312781268
# heading_error  -5.22341618778438
# absHeadingError  5.22341618778438
# PWM1  155.29018978821026 PWM2  155.29018978821026 mode  -1
# 155.29018978821026,155.29018978821026,-1
# target_centre  [545.5 177. ]
# robot_centre  [396. 208.]
# robot_heading  109.09349200048563
# target_vector  [149.5 -31. ]
# target_angle  101.71471287809376
# heading_error  -7.3787791223918475
# absHeadingError  7.3787791223918475
# PWM1  155.40993217346622 PWM2  155.40993217346622 mode  -1
# 155.40993217346622,155.40993217346622,-1
# target_centre  [544.5 177. ]
# robot_centre  [399.25 206.5 ]
# robot_heading  108.75865034784223
# target_vector  [145.25 -29.5 ]
# target_angle  101.48051153193957
# heading_error  -7.2781388159026505
# absHeadingError  7.2781388159026505
# PWM1  155.40434104532793 PWM2  155.40434104532793 mode  -1
# 155.40434104532793,155.40434104532793,-1
# target_centre  [544.5 177. ]
# robot_centre  [402. 206.]
# robot_heading  107.10272896905236
# target_vector  [142.5 -29. ]
# target_angle  101.50310699328836
# heading_error  -5.599621975764023
# absHeadingError  5.599621975764023
# PWM1  155.31109010976468 PWM2  155.31109010976468 mode  -1
# 155.31109010976468,155.31109010976468,-1
# 427.295345750454
# rotationDirection  -1
# target_centre  [544.  176.5]
# robot_centre  [404.5  205.25]
# robot_heading  106.09081634885217
# target_vector  [139.5  -28.75]
# target_angle  101.64522236496802
# heading_error  -4.445593983884152
# absHeadingError  4.445593983884152
# PWM1  177.25388608429955 PWM2  175.47564849074587 mode  0
# 177.25388608429955,175.47564849074587,0
# 422.30861049711024
# rotationDirection  -1
# target_centre  [544.  176.5]
# robot_centre  [406.25 205.5 ]
# robot_heading  104.79676224505735
# target_vector  [137.75 -29.  ]
# target_angle  101.88865803962798
# heading_error  -2.9081042054293675
# absHeadingError  2.9081042054293675
# PWM1  176.6970513659414 PWM2  175.53380968376965 mode  0
# 176.6970513659414,175.53380968376965,0
# 418.0629438254483
# rotationDirection  -1
# target_centre  [544.  176.5]
# robot_centre  [407.75 205.75]
# robot_heading  103.78159723565363
# target_vector  [136.25 -29.25]
# target_angle  102.11629414385129
# heading_error  -1.6653030918023433
# absHeadingError  1.6653030918023433
# PWM1  175.9031471912724 PWM2  175.9031471912724 mode  0
# 175.9031471912724,175.9031471912724,0
# 395.63690740374557
# rotationDirection  1
# target_centre  [544.  175.5]
# robot_centre  [416.   207.25]
# robot_heading  99.46232220802563
# target_vector  [128.   -31.75]
# target_angle  103.93087203819292
# heading_error  4.468549830167291
# absHeadingError  4.468549830167291
# PWM1  173.88813540415381 PWM2  175.67555533622075 mode  0
# 173.88813540415381,175.67555533622075,0
# 387.9965367113474
# rotationDirection  1
# target_centre  [544.5 175.5]
# robot_centre  [419.   206.75]
# robot_heading  99.46232220802563
# target_vector  [125.5  -31.25]
# target_angle  103.98252029612904
# heading_error  4.520198088103427
# absHeadingError  4.520198088103427
# PWM1  173.49578721794668 PWM2  175.30386645318808 mode  0
# 173.49578721794668,175.30386645318808,0
# 379.26722109879205
# rotationDirection  1
# target_centre  [545.  175.5]
# robot_centre  [422.25 205.75]
# robot_heading  99.29330859939712
# target_vector  [122.75 -30.25]
# target_angle  103.84388425943467
# heading_error  4.550575660037566
# absHeadingError  4.550575660037566
# PWM1  173.0532459229321 PWM2  174.87347618694713 mode  0
# 173.0532459229321,174.87347618694713,0
# 370.54023060930916
# rotationDirection  1
# target_centre  [546. 176.]
# robot_centre  [426.   205.25]
# robot_heading  99.46232220802563
# target_vector  [120.   -29.25]
# target_angle  103.69871700708445
# heading_error  4.236394799058814
# absHeadingError  4.236394799058814
# PWM1  172.6797325706537 PWM2  174.37429049027725 mode  0
# 172.6797325706537,174.37429049027725,0
# 359.6201120627154
# rotationDirection  1
# target_centre  [546. 175.]
# robot_centre  [429.75 204.25]
# robot_heading  99.29330859939712
# target_vector  [116.25 -29.25]
# target_angle  104.1231869209396
# heading_error  4.8298783215424805
# absHeadingError  4.8298783215424805
# PWM1  172.01502993882727 PWM2  173.94698126744427 mode  0
# 172.01502993882727,173.94698126744427,0
# target_centre  [547. 175.]
# robot_centre  [433.25 204.  ]
# robot_heading  98.2758928270752
# target_vector  [113.75 -29.  ]
# target_angle  104.30259589613586
# heading_error  6.026703069060659
# absHeadingError  6.026703069060659
# PWM1  155.33481683717002 PWM2  155.33481683717002 mode  1
# 155.33481683717002,155.33481683717002,1
# target_centre  [547. 175.]
# robot_centre  [436.75 203.5 ]
# robot_heading  98.2758928270752
# target_vector  [110.25 -28.5 ]
# target_angle  104.49386775827615
# heading_error  6.217974931200956
# absHeadingError  6.217974931200956
# PWM1  155.34544305173338 PWM2  155.34544305173338 mode  1
# 155.34544305173338,155.34544305173338,1
# target_centre  [549. 175.]
# robot_centre  [444.5 202. ]
# robot_heading  98.13010235415598
# target_vector  [104.5 -27. ]
# target_angle  104.48687513838556
# heading_error  6.356772784229577
# absHeadingError  6.356772784229577
# PWM1  155.3531540435683 PWM2  155.3531540435683 mode  1
# 155.3531540435683,155.3531540435683,1
# target_centre  [548.5 174.5]
# robot_centre  [447.75 201.25]
# robot_heading  99.29330859939712
# target_vector  [100.75 -26.75]
# target_angle  104.86945668064851
# heading_error  5.576148081251404
# absHeadingError  5.576148081251404
# PWM1  155.30978600451397 PWM2  155.30978600451397 mode  1
# 155.30978600451397,155.30978600451397,1
# target_centre  [549.  174.5]
# robot_centre  [451.  200.5]
# robot_heading  96.3401917459099
# target_vector  [ 98. -26.]
# target_angle  104.85861444792467
# heading_error  8.51842270201476
# absHeadingError  8.51842270201476
# PWM1  155.4732457056675 PWM2  155.4732457056675 mode  1
# 155.4732457056675,155.4732457056675,1
# 297.79533659881247
# rotationDirection  1
# target_centre  [549.  174.5]
# robot_centre  [453.   199.75]
# robot_heading  101.1130405359483
# target_vector  [ 96.   -25.25]
# target_angle  104.73621816537738
# heading_error  3.6231776294290796
# absHeadingError  3.6231776294290796
# PWM1  169.1651313040548 PWM2  170.61440235582643 mode  0
# 169.1651313040548,170.61440235582643,0
# 294.89500250089014
# rotationDirection  1
# target_centre  [549. 174.]
# robot_centre  [454.   199.25]
# robot_heading  101.513831184487
# target_vector  [ 95.   -25.25]
# target_angle  104.88448421065863
# heading_error  3.370653026171624
# absHeadingError  3.370653026171624
# PWM1  169.07061951981018 PWM2  170.41888073027883 mode  0
# 169.07061951981018,170.41888073027883,0
# 291.58896584061614
# rotationDirection  1
# target_centre  [549. 174.]
# robot_centre  [454.75 197.75]
# robot_heading  103.29857033049429
# target_vector  [ 94.25 -23.75]
# target_angle  104.1434718758257
# heading_error  0.8449015453314246
# absHeadingError  0.8449015453314246
# PWM1  169.5794482920308 PWM2  169.5794482920308 mode  0
# 169.5794482920308,169.5794482920308,0
# 288.6837586356392
# rotationDirection  1
# target_centre  [549. 174.]
# robot_centre  [455.5  196.75]
# robot_heading  103.53585636913425
# target_vector  [ 93.5  -22.75]
# target_angle  103.67521623906792
# heading_error  0.13935986993368488
# absHeadingError  0.13935986993368488
# PWM1  169.43418793178196 PWM2  169.43418793178196 mode  0
# 169.43418793178196,169.43418793178196,0
# 283.9975792150349
# rotationDirection  -1
# target_centre  [549. 174.]
# robot_centre  [456.75 195.25]
# robot_heading  105.25511870305779
# target_vector  [ 92.25 -21.25]
# target_angle  102.97193437840903
# heading_error  -2.2831843246487438
# absHeadingError  2.2831843246487438
# PWM1  169.65651582568148 PWM2  168.74324209582198 mode  0
# 169.65651582568148,168.74324209582198,0
# 280.17494534665303
# rotationDirection  -1
# target_centre  [549. 174.]
# robot_centre  [458. 195.]
# robot_heading  104.53445508054013
# target_vector  [ 91. -21.]
# target_angle  102.9946167919165
# heading_error  -1.5398382886236277
# absHeadingError  1.5398382886236277
# PWM1  169.00874726733264 PWM2  169.00874726733264 mode  0
# 169.00874726733264,169.00874726733264,0
# 273.4950867931634
# rotationDirection  -1
# target_centre  [549. 174.]
# robot_centre  [460.   193.75]
# robot_heading  105.52411099675426
# target_vector  [ 89.   -19.75]
# target_angle  102.51176553847235
# heading_error  -3.0123454582819136
# absHeadingError  3.0123454582819136
# PWM1  169.27722343131455 PWM2  168.07228524800178 mode  0
# 169.27722343131455,168.07228524800178,0
# 265.6863752622629
# rotationDirection  -1
# target_centre  [549. 174.]
# robot_centre  [462.5 193. ]
# robot_heading  106.50436138175503
# target_vector  [ 86.5 -19. ]
# target_angle  102.38846315330854
# heading_error  -4.115898228446497
# absHeadingError  4.115898228446497
# PWM1  169.10749840880243 PWM2  167.46113911742384 mode  0
# 169.10749840880243,167.46113911742384,0
# 255.94237632717255
# rotationDirection  -1
# target_centre  [549. 174.]
# robot_centre  [465.5 191.5]
# robot_heading  106.50436138175503
# target_vector  [ 83.5 -17.5]
# target_angle  101.83677536786274
# heading_error  -4.667586013892276
# absHeadingError  4.667586013892276
# PWM1  168.73063601913708 PWM2  166.86360161358016 mode  0
# 168.73063601913708,166.86360161358016,0
# 248.29418035870276
# rotationDirection  -1
# target_centre  [548.5 174. ]
# robot_centre  [467.5 191. ]
# robot_heading  105.06848815949222
# target_vector  [ 81. -17.]
# target_angle  101.853004167744
# heading_error  -3.215483991748215
# absHeadingError  3.215483991748215
# PWM1  168.05780581628477 PWM2  166.7716122195855 mode  0
# 168.05780581628477,166.7716122195855,0
